# %% [markdown]
# # Solving PDEs with ModelingToolkit and NeuralPDE
#
# https://docs.sciml.ai/NeuralPDE/stable/tutorials/pdesystem/
#
# Solving Poisson PDE Systems
#
# $$
# \partial^{2}_{x}u(x,y) + \partial^{2}_{y}u(x,y) = -\sin (\pi x) \sin (\pi y)
# $$
#
# with boundary conditions
#
# $$
# \begin{align}
# u(0, y) &= 0 \\
# u(1, y) &= 0 \\
# u(x, 0) &= 0 \\
# u(x, 1) &= 0 \\
# \end{align}
# $$
#
# where
#
# $x ∈ [0, 1], y ∈ [0, 1]$

# %%
using NeuralPDE
using Lux
using Optimization
using OptimizationOptimJL
using ModelingToolkit
using ModelingToolkit: Interval
using LineSearches
using Plots
Plots.default(fmt=:png)

# %%
@parameters x y
@variables u(..)
Dxx = Differential(x)^2
Dyy = Differential(y)^2

# %% [markdown]
# 2D PDE equations

# %%
eq  = Dxx(u(x, y)) + Dyy(u(x, y)) ~ -sinpi(x) * sinpi(y)

# %% [markdown]
# Boundary conditions

# %%
bcs = [
    u(0, y) ~ 0.0, u(1, y) ~ 0.0,
    u(x, 0) ~ 0.0, u(x, 1) ~ 0.0
]

# %% [markdown]
# Space domains

# %%
domains = [
    x ∈ Interval(0.0, 1.0),
    y ∈ Interval(0.0, 1.0)
]

# %% [markdown]
# Build a neural network for the PDE solver.

# %%
dim = 2
chain = Lux.Chain(Dense(dim, 16, Lux.σ), Dense(16, 16, Lux.σ), Dense(16, 1))

# %% [markdown]
# Discretization method uses `PhysicsInformedNN()` (PINN).

# %%
dx = 0.05
discretization = PhysicsInformedNN(chain, QuadratureTraining(; batch = 200, abstol = 1e-6, reltol = 1e-6))

# %% [markdown]
# Next we build our PDE system and discretize it.
# Because this system is time-invariant, the result is an `OptimizationProblem`.

# %%
@named pde_system = PDESystem(eq, bcs, domains, [x, y], [u(x, y)])
prob = discretize(pde_system, discretization)

# %%
opt = OptimizationOptimJL.LBFGS(linesearch = BackTracking())

# %% [markdown]
# Callback function

# %%
larr = Float64[]
callback = function (p, l)
    push!(larr, l)
    return false
end

# %% [markdown]
# Solve the problem.

# %%
res = Optimization.solve(prob, opt, callback = callback, maxiters=1500)
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] (::Cubature.var"#17#18"{Bool, Bool, Int64, Float64, Float64, Int64, Int32, Ptr{Nothing}, Cubature.IntegrandData{IntegralsCubatureExt.var"#8#15"{IntegralProblem{false, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, IntegralFunction{false, SciMLBase.FullSpecialize, IntegralsZygoteExt.var"#17#29"{Array{Float64, 0}, Integrals.IntegralCache{false, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, @Kwargs{}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, @Kwargs{}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}}, Vector{Float64}, Vector{Float64}, Vector{Float64}, Vector{Float64}, Int64})()
#     @ Cubature ~/.julia/packages/Cubature/5zwuu/src/Cubature.jl:215
#   [2] disable_sigint
#     @ ./c.jl:473 [inlined]
#   [3] cubature(xscalar::Bool, fscalar::Bool, vectorized::Bool, padaptive::Bool, fdim::Int64, f::IntegralsCubatureExt.var"#8#15"{IntegralProblem{false, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, IntegralFunction{false, SciMLBase.FullSpecialize, IntegralsZygoteExt.var"#17#29"{Array{Float64, 0}, Integrals.IntegralCache{false, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, @Kwargs{}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, @Kwargs{}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, xmin_::Vector{Float64}, xmax_::Vector{Float64}, reqRelError::Float64, reqAbsError::Float64, maxEval::Int64, error_norm::Int32)
#     @ Cubature ~/.julia/packages/Cubature/5zwuu/src/Cubature.jl:169
#   [4] hcubature(fdim::Int64, f::Function, xmin::Vector{Float64}, xmax::Vector{Float64}; reltol::Float64, abstol::Float64, maxevals::Int64, error_norm::Int32)
#     @ Cubature ~/.julia/packages/Cubature/5zwuu/src/Cubature.jl:227
#   [5] __solvebp_call(prob::IntegralProblem{false, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, IntegralFunction{false, SciMLBase.FullSpecialize, IntegralsZygoteExt.var"#17#29"{Array{Float64, 0}, Integrals.IntegralCache{false, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, @Kwargs{}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, @Kwargs{}}, alg::Integrals.CubatureJLh, sensealg::Integrals.ReCallVJP{Integrals.ZygoteVJP}, domain::Tuple{Vector{Float64}, Vector{Float64}}, p::ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}; reltol::Float64, abstol::Float64, maxiters::Int64)
#     @ IntegralsCubatureExt ~/.julia/packages/Integrals/tvunm/ext/IntegralsCubatureExt.jl:148
#   [6] __solvebp_call
#     @ ~/.julia/packages/Integrals/tvunm/ext/IntegralsCubatureExt.jl:7 [inlined]
#   [7] #__solvebp_call#4
#     @ ~/.julia/packages/Integrals/tvunm/src/common.jl:115 [inlined]
#   [8] __solvebp_call
#     @ ~/.julia/packages/Integrals/tvunm/src/common.jl:114 [inlined]
#   [9] (::IntegralsZygoteExt.var"#quadrature_adjoint#21"{@Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Integrals.IntegralCache{false, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, @Kwargs{}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Nothing}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}})(Δ::Array{Float64, 0})
#     @ IntegralsZygoteExt ~/.julia/packages/Integrals/tvunm/ext/IntegralsZygoteExt.jl:96
#  [10] ZBack
#     @ ~/.julia/packages/Zygote/nsBv0/src/compiler/chainrules.jl:211 [inlined]
#  [11] (::Zygote.var"#kw_zpullback#53"{IntegralsZygoteExt.var"#quadrature_adjoint#21"{@Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Integrals.IntegralCache{false, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, @Kwargs{}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Nothing}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}})(dy::Array{Float64, 0})
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/compiler/chainrules.jl:237
#  [12] solve!
#     @ ~/.julia/packages/Integrals/tvunm/src/common.jl:105 [inlined]
#  [13] (::Zygote.Pullback{Tuple{typeof(solve!), Integrals.IntegralCache{false, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, @Kwargs{}, Integrals.CubatureJLh, Integrals.ReCallVJP{Integrals.ZygoteVJP}, @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, Nothing}}, Any})(Δ::Array{Float64, 0})
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/compiler/interface2.jl:0
#  [14] #solve#3
#     @ ~/.julia/packages/Integrals/tvunm/src/common.jl:101 [inlined]
#  [15] (::Zygote.Pullback{Tuple{Integrals.var"##solve#3", @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, typeof(solve), IntegralProblem{false, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, @Kwargs{}}, Integrals.CubatureJLh}, Any})(Δ::Array{Float64, 0})
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/compiler/interface2.jl:0
#  [16] solve
#     @ ~/.julia/packages/Integrals/tvunm/src/common.jl:98 [inlined]
#  [17] (::Zygote.Pullback{Tuple{typeof(Core.kwcall), @NamedTuple{reltol::Float64, abstol::Float64, maxiters::Int64}, typeof(solve), IntegralProblem{false, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, @Kwargs{}}, Integrals.CubatureJLh}, Tuple{Zygote.Pullback{Tuple{Integrals.var"##solve#3", @Kwargs{reltol::Float64, abstol::Float64, maxiters::Int64}, typeof(solve), IntegralProblem{false, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing}, Tuple{Vector{Float64}, Vector{Float64}}, @Kwargs{}}, Integrals.CubatureJLh}, Any}, Zygote.var"#2366#back#419"{Zygote.var"#pairs_namedtuple_pullback#418"{(:reltol, :abstol, :maxiters), @NamedTuple{reltol::Float64, abstol::Float64, maxiters::Int64}}}}})(Δ::Array{Float64, 0})
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/compiler/interface2.jl:0
#  [18] #134
#     @ ~/.julia/packages/NeuralPDE/IUP3N/src/training_strategies.jl:317 [inlined]
#  [19] (::Zygote.Pullback{Tuple{NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, Tuple{Zygote.var"#2210#back#313"{Zygote.Jnew{NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}}, Nothing, false}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:strategy, Zygote.Context{false}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, QuadratureTraining{Integrals.CubatureJLh, Float64}}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:reltol, :abstol, :maxiters)}}, Tuple{Float64, Float64, Int64}}, Tuple{Zygote.var"#2220#back#315"{Zygote.Jnew{@NamedTuple{reltol::Float64, abstol::Float64, maxiters::Int64}, Nothing, true}}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:quadrature_alg, Zygote.Context{false}, QuadratureTraining{Integrals.CubatureJLh, Float64}, Integrals.CubatureJLh}}, Zygote.var"#2013#back#204"{typeof(identity)}, Zygote.Pullback{Tuple{typeof(Zygote.literal_getindex), SciMLBase.IntegralSolution{Float64, 0, Float64, Float64, IntegralProblem{false, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, BatchIntegralFunction{false, SciMLBase.FullSpecialize, NeuralPDE.var"#integrand#138"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p),  ...
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/compiler/interface2.jl:0
#  [20] #135
#     @ ~/.julia/packages/NeuralPDE/IUP3N/src/training_strategies.jl:323 [inlined]
#  [21] (::Zygote.Pullback{Tuple{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:f_, Zygote.Context{false}, NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}}}, Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:area, Zygote.Context{false}, NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}, Float64}}, Zygote.ZBack{ChainRules.var"#times_pullback2#419"{Float64, Float64}}, Zygote.ZBack{ChainRules.var"# ...
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/compiler/interface2.jl:0
#  [22] #324
#     @ ./none:0 [inlined]
#  [23] (::Zygote.Pullback{Tuple{NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:θ, Zygote.Context{false}, NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}}, Zygote.Pullback{Tuple{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:27 ...
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/compiler/interface2.jl:0
#  [24] #665
#     @ ~/.julia/packages/Zygote/nsBv0/src/lib/array.jl:201 [inlined]
#  [25] #4
#     @ ./generator.jl:36 [inlined]
#  [26] iterate
#     @ ./generator.jl:47 [inlined]
#  [27] collect(itr::Base.Generator{Base.Iterators.Zip{Tuple{Vector{Tuple{Float64, Zygote.Pullback{Tuple{NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:θ, Zygote.Context{false}, NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}}, Zygote.Pullback{Tuple{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axi ...
#     @ Base ./array.jl:834
#  [28] map
#     @ ./abstractarray.jl:3409 [inlined]
#  [29] (::Zygote.var"#map_back#667"{NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, 1, Tuple{Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}}, Tuple{Tuple{Base.OneTo{Int64}}}, Vector{Tuple{Float64, Zygote.Pullback{Tuple{NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:θ, Zygote.Context{false}, NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), la ...
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/lib/array.jl:201
#  [30] (::Zygote.var"#collect_pullback#705"{Zygote.var"#map_back#667"{NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, 1, Tuple{Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}}, Tuple{Tuple{Base.OneTo{Int64}}}, Vector{Tuple{Float64, Zygote.Pullback{Tuple{NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, Tuple{Zygote.var"#2180#back#303"{Zygote.var"#back#302"{:θ, Zygote.Context{false}, NeuralPDE.var"#324#345"{ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis ...
#     @ Zygote ~/.julia/packages/Zygote/nsBv0/src/lib/array.jl:235
#  [31] full_loss_function
#     @ ~/.julia/packages/NeuralPDE/IUP3N/src/discretize.jl:540 [inlined]
# ...
#     @ Optim ~/.julia/packages/Optim/ZhuZN/src/multivariate/optimize/optimize.jl:59
#  [53] optimize(d::TwiceDifferentiable{Float64, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, ComponentArrays.ComponentMatrix{Float64, Matrix{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}, ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}}, initial_x::ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, method::LBFGS{Nothing, InitialStatic{Float64}, BackTracking{Float64, Int64}, Optim.var"#20#22"}, options::Optim.Options{Float64, OptimizationOptimJL.var"#_cb#12"{OptimizationCache{OptimizationFunction{true, AutoZygote, NeuralPDE.var"#full_loss_function#344"{NeuralPDE.var"#null_nonadaptive_loss#147", Vector{NeuralPDE.var"#135#139"{loss_function, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64} where loss_function}, Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, NeuralPDE.PINNRepresentation, Bool, Vector{Int64}, Int64, NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid ...
#     @ Optim ~/.julia/packages/Optim/ZhuZN/src/multivariate/optimize/optimize.jl:36
#  [54] __solve(cache::OptimizationCache{OptimizationFunction{true, AutoZygote, NeuralPDE.var"#full_loss_function#344"{NeuralPDE.var"#null_nonadaptive_loss#147", Vector{NeuralPDE.var"#135#139"{loss_function, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64} where loss_function}, Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, NeuralPDE.PINNRepresentation, Bool, Vector{Int64}, Int64, NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing, Bool}, OptimizationZygoteExt.var"#38#56"{OptimizationZygoteExt.var"#37#55"{OptimizationFunction{true, AutoZygote, NeuralPDE.var"#full_loss_function#344"{NeuralPDE.var"#null_nonadaptive_loss#147", Vector{NeuralPDE.var"#135#139"{loss_function, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64} where loss_function}, Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, NeuralPDE.PINNRepresentation, Bool, Vector{Int64}, Int64, NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing, Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Optimiza ...
#     @ OptimizationOptimJL ~/.julia/packages/OptimizationOptimJL/hDX5k/src/OptimizationOptimJL.jl:224
#  [55] solve!(cache::OptimizationCache{OptimizationFunction{true, AutoZygote, NeuralPDE.var"#full_loss_function#344"{NeuralPDE.var"#null_nonadaptive_loss#147", Vector{NeuralPDE.var"#135#139"{loss_function, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64} where loss_function}, Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, NeuralPDE.PINNRepresentation, Bool, Vector{Int64}, Int64, NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing, Bool}, OptimizationZygoteExt.var"#38#56"{OptimizationZygoteExt.var"#37#55"{OptimizationFunction{true, AutoZygote, NeuralPDE.var"#full_loss_function#344"{NeuralPDE.var"#null_nonadaptive_loss#147", Vector{NeuralPDE.var"#135#139"{loss_function, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64} where loss_function}, Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, NeuralPDE.PINNRepresentation, Bool, Vector{Int64}, Int64, NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing, Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Optimizat ...
#     @ SciMLBase ~/.julia/packages/SciMLBase/OXryf/src/solve.jl:188
#  [56] solve(::OptimizationProblem{true, OptimizationFunction{true, AutoZygote, NeuralPDE.var"#full_loss_function#344"{NeuralPDE.var"#null_nonadaptive_loss#147", Vector{NeuralPDE.var"#135#139"{loss_function, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64} where loss_function}, Vector{NeuralPDE.var"#135#139"{NeuralPDE.var"#240#241"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:cord, Symbol("##θ#226"), :phi, :derivative, :integral, :u, :p), NeuralPDE.var"#_RGF_ModTag", NeuralPDE.var"#_RGF_ModTag", (0x1ce57079, 0xf273e00d, 0x16384951, 0xab04aa4d, 0xdf76f0a5), Expr}, NeuralPDE.var"#32#33", NeuralPDE.var"#300#307"{NeuralPDE.var"#300#301#308"{typeof(NeuralPDE.numeric_derivative)}, Dict{Symbol, Int64}, Dict{Symbol, Int64}, QuadratureTraining{Integrals.CubatureJLh, Float64}}, typeof(NeuralPDE.numeric_derivative), NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing}, Vector{Float64}, Vector{Float64}, NeuralPDE.var"#134#137"{QuadratureTraining{Integrals.CubatureJLh, Float64}}, Float64}}, NeuralPDE.PINNRepresentation, Bool, Vector{Int64}, Int64, NeuralPDE.Phi{Chain{@NamedTuple{layer_1::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_2::Dense{true, typeof(sigmoid_fast), typeof(glorot_uniform), typeof(zeros32)}, layer_3::Dense{true, typeof(identity), typeof(glorot_uniform), typeof(zeros32)}}, Nothing}, @NamedTuple{layer_1::@NamedTuple{}, layer_2::@NamedTuple{}, layer_3::@NamedTuple{}}}, Nothing, Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, ComponentArrays.ComponentVector{Float64, Vector{Float64}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:48, Axis(weight = ViewAxis(1:32, ShapedAxis((16, 2))), bias = ViewAxis(33:48, ShapedAxis((16, 1))))), layer_2 = ViewAxis(49:320, Axis(weight = ViewAxis(1:256, ShapedAxis((16, 16))), bias = ViewAxis(257:272, ShapedAxis((16, 1))))), layer_3 = ViewAxis(321:337, Axis(weight = ViewAxis(1:16, ShapedAxis((1, 16))), bias = ViewAxis(17:17, ShapedAxis((1, 1))))))}}}, SciMLBase.NullParameters, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, @Kwargs{}}, ::LBFGS{Nothing, InitialStatic{Float64}, BackTracking{Float64, Int64}, Optim.var"#20#22"}; kwargs::@Kwargs{callback::var"#3#4", maxiters::Int64})
#     @ SciMLBase ~/.julia/packages/SciMLBase/OXryf/src/solve.jl:96

# %%
plot(larr, xlabel="Iters", title="Loss", yscale=:log10, lab="Loss")

# %% [markdown]
# Plot the predicted solution of the PDE and compare it with the analytical solution to see the relative error.

# %%
xs, ys = [infimum(d.domain):dx/10:supremum(d.domain) for d in domains]
analytic_sol_func(x,y) = (sinpi(x)*sinpi(y))/(2pi^2)

phi = discretization.phi
u_predict = reshape([first(phi([x, y], res.u)) for x in xs for y in ys], (length(xs), length(ys)))
u_real = reshape([analytic_sol_func(x, y) for x in xs for y in ys], (length(xs), length(ys)))
diff_u = abs.(u_predict .- u_real)

# %%
p1 = plot(xs, ys, u_real, linetype=:contourf, title = "analytic");
p2 = plot(xs, ys, u_predict, linetype=:contourf, title = "predict");
p3 = plot(xs, ys, diff_u, linetype=:contourf, title = "error");
plot(p1, p2, p3)
